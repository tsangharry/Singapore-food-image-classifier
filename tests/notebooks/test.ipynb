# %%
import cv2

# %%
from src.inference import resize_image, predict_image, load_model

# %%
model = load_model("model/model.h5")

# %%
model.summary()
# Out:
#
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# ...

# %%
a = resize_image("img/test-chilli-crab.png")
a.shape
# Out:
# (1, 299, 299, 3)

# %%
prediction_prob = model.predict(a)

# %%
prediction_prob
# Out:
# array([[9.9202889e-01, 4.0129966e-05, 6.7262595e-06, 6.0369484e-07,
#         4.1910187e-07, 1.2378761e-04, 1.7657059e-05, 8.2096903e-06,
#         2.3550224e-04, 7.4365949e-03, 1.3699621e-06, 1.0002747e-04]],
#       dtype=float32)

# %%
import numpy as np
foods = ['chilli_crab',
        'curry_puff',
        'dim_sum',
        'ice_kacang',
        'kaya_toast',
        'nasi_ayam',
        'popiah',
        'roti_prata',
        'sambal_stingray',
        'satay',
        'tau_huay',
        'wanton_noodle']
foods[np.argmax(prediction_prob)]
# Out:
# 'chilli_crab'

# %%
prediction_prob_list = [0.999]
for i in range(0,11):
    n = random.randint(1,9)/10
    prediction_prob_list.append(n)
prediction_prob = np.array(prediction_prob_list)

# %%
prediction_prob
# Out:
# array([0.999, 0.6  , 0.6  , 0.6  , 0.4  , 0.4  , 0.6  , 0.3  , 0.8  ,
#        0.6  , 0.6  , 0.3  ])

# %%
probability = np.max(prediction_prob)

# %%
probability
# Out:
# 0.999
